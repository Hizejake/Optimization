# %% [markdown]
# # Prepare Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.dropna(inplace=True)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 18.2+ KB

# %%
titanic.drop(['deck', 'embark_town', 'alive','who','embarked','sex','class'],inplace = True, axis = 1)
titanic
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone
# 1           1       1  38.0      1      0  71.2833       False  False
# 3           1       1  35.0      1      0  53.1000       False  False
# 6           0       1  54.0      0      0  51.8625        True   True
# 10          1       3   4.0      1      1  16.7000       False  False
# 11          1       1  58.0      0      0  26.5500       False   True
# ..        ...     ...   ...    ...    ...      ...         ...    ...
# 871         1       1  47.0      1      1  52.5542       False  False
# 872         0       1  33.0      0      0   5.0000        True   True
# 879         1       1  56.0      0      1  83.1583       False  False
# 887         1       1  19.0      0      0  30.0000       False   True
# 889         1       1  26.0      0      0  30.0000        True   True
#
# [182 rows x 8 columns]

# %% [markdown]
# <h1 style="color: #FF0000;"> Hence forth y = titanic['survived'] is a global variable

# %%
y = titanic['survived']

# %% [markdown]
# # Define Linear Regression

# %% [markdown]
# ## Define Normalize

# %%
def normalize(X):
    for i in pd.DataFrame(X).columns:
        if X[i].dtype == 'bool':
            X[i] = X[i]
        else:
            X[i] = (X[i] - X[i].mean())/X[i].std()
    return X
# normalize(titanic)

# %% [markdown]
# ## Define Gradient Descend

# %%
def gradient_descend(X, y, learning_rate = 0.01, n_iter = 1000):
    X = normalize(X)
    X = np.c_[np.ones(X.shape[0]), X]
    theta = np.zeros(X.shape[1])
    m = X.shape[0]
    
    for i in range(n_iter):
        h = X @ theta
        loss = (h - y)
        gradient = X.T @ loss / m
        theta = theta - (learning_rate * gradient)
    return theta

# %% [markdown]
# ### Testing if the regression works

# %%
# x = (titanic.drop('survived', axis = 1))
# y = (titanic['survived'])
# theta = gradient_descend(X=x, y=y, learning_rate = 0.01, n_iter = 1000)
# theta

# %% [markdown]
# # Define Fitness Function
#     Here we are using Akaike information criterion which is given by the formula
#
# AIC = 2k - 2ln(L^)
#
# where k = number of estimated parameters
#       L^ = maximised value of likelihood function

# %%
def rss(X,y,theta):
    X = normalize(X)
    X = np.c_[np.ones(X.shape[0]), X]
    residual_sum_squares = sum(((X @ theta) - y)**2)
    return residual_sum_squares

def calculate_aic(X,y,theta):
    n = len(y)
    aic = 2 * X.shape[1] + n * np.log(rss(X,y,theta) / n)
    return aic

# %%
# x = (titanic.drop('survived', axis = 1))
# y = (titanic['survived'])
# theta = gradient_descend(X=x, y=y, learning_rate = 0.01, n_iter = 1000)
# calculate_aic(x,y,theta)

# %% [markdown]
# # Generate Parent Population

# %%
def parent_pops(data,size,y):
    papa_pops = []
    df_temp = data.drop(y, axis = 1)
    for i in range(size):
        feature_arrs = np.random.choice([True,False],size = df_temp.shape[1])
        papa_pops.append(df_temp.iloc[:, np.where(feature_arrs)[0]])
    return papa_pops

# %%
parent_pops(titanic,10,'survived')
# Out:
# [     pclass     fare  adult_male
#  1         1  71.2833       False
#  3         1  53.1000       False
#  6         1  51.8625        True
#  10        3  16.7000       False
#  11        1  26.5500       False
#  ..      ...      ...         ...
#  871       1  52.5542       False
#  872       1   5.0000        True
#  879       1  83.1583       False
#  887       1  30.0000       False
#  889       1  30.0000        True
#
#  [182 rows x 3 columns],
#        age  sibsp  parch  adult_male
#  1    38.0      1      0       False
#  3    35.0      1      0       False
#  6    54.0      0      0        True
#  10    4.0      1      1       False
#  11   58.0      0      0       False
#  ..    ...    ...    ...         ...
#  871  47.0      1      1       False
#  872  33.0      0      0        True
#  879  56.0      0      1       False
#  887  19.0      0      0       False
#  889  26.0      0      0        True
#
#  [182 rows x 4 columns],
#       parch  alone
#  1        0  False
#  3        0  False
#  6        0   True
#  10       1  False
#  11       0   True
#  ..     ...    ...
#  871      1  False
#  872      0   True
#  879      1  False
#  887      0   True
#  889      0   True
#
#  [182 rows x 2 columns],
#       pclass  sibsp     fare  adult_male
#  1         1      1  71.2833       False
#  3         1      1  53.1000       False
#  6         1      0  51.8625        True
#  10        3      1  16.7000       False
#  11        1      0  26.5500       False
#  ..      ...    ...      ...         ...
#  871       1      1  52.5542       False
#  872       1      0   5.0000        True
#  879       1      0  83.1583       False
#  887       1      0  30.0000       False
#  889       1      0  30.0000        True
#
#  [182 rows x 4 columns],
#       pclass   age  sibsp     fare  adult_male
#  1         1  38.0      1  71.2833       False
#  3         1  35.0      1  53.1000       False
#  6         1  54.0      0  51.8625        True
#  10        3   4.0      1  16.7000       False
#  11        1  58.0      0  26.5500       False
#  ..      ...   ...    ...      ...         ...
#  871       1  47.0      1  52.5542       False
#  872       1  33.0      0   5.0000        True
#  879       1  56.0      0  83.1583       False
#  887       1  19.0      0  30.0000       False
#  889       1  26.0      0  30.0000        True
#
#  [182 rows x 5 columns],
#       pclass   age  parch     fare
#  1         1  38.0      0  71.2833
#  3         1  35.0      0  53.1000
#  6         1  54.0      0  51.8625
#  10        3   4.0      1  16.7000
#  11        1  58.0      0  26.5500
#  ..      ...   ...    ...      ...
#  871       1  47.0      1  52.5542
#  872       1  33.0      0   5.0000
#  879       1  56.0      1  83.1583
#  887       1  19.0      0  30.0000
#  889       1  26.0      0  30.0000
#
#  [182 rows x 4 columns],
#       sibsp     fare
#  1        1  71.2833
#  3        1  53.1000
#  6        0  51.8625
#  10       1  16.7000
#  11       0  26.5500
#  ..     ...      ...
#  871      1  52.5542
#  872      0   5.0000
#  879      0  83.1583
#  887      0  30.0000
#  889      0  30.0000
#
#  [182 rows x 2 columns],
#       sibsp     fare  adult_male  alone
#  1        1  71.2833       False  False
#  3        1  53.1000       False  False
#  6        0  51.8625        True   True
#  10       1  16.7000       False  False
#  11       0  26.5500       False   True
#  ..     ...      ...         ...    ...
#  871      1  52.5542       False  False
#  872      0   5.0000        True   True
#  879      0  83.1583       False  False
#  887      0  30.0000       False   True
#  889      0  30.0000        True   True
#
#  [182 rows x 4 columns],
#        age  parch     fare  adult_male
#  1    38.0      0  71.2833       False
#  3    35.0      0  53.1000       False
#  6    54.0      0  51.8625        True
#  10    4.0      1  16.7000       False
#  11   58.0      0  26.5500       False
#  ..    ...    ...      ...         ...
#  871  47.0      1  52.5542       False
#  872  33.0      0   5.0000        True
#  879  56.0      1  83.1583       False
#  887  19.0      0  30.0000       False
#  889  26.0      0  30.0000        True
#
#  [182 rows x 4 columns],
#        age  adult_male  alone
#  1    38.0       False  False
#  3    35.0       False  False
#  6    54.0        True   True
#  10    4.0       False  False
#  11   58.0       False   True
#  ..    ...         ...    ...
#  871  47.0       False  False
#  872  33.0        True   True
#  879  56.0       False  False
#  887  19.0       False   True
#  889  26.0        True   True
#
#  [182 rows x 3 columns]]

# %% [markdown]
# ## Calculate fitness score for parents

# %%
def parent_score(keys):
    pop_score = {}
    temp_var = 0
    for key in keys:
        theta1 = gradient_descend(key, y, learning_rate = 0.01, n_iter = 1000)
        aic = -1*calculate_aic(key,y,theta1)
        pop_score[temp_var] = aic
        temp_var += 1
    return pop_score

# %%
parent_score(parent_pops(titanic,10,'survived'),titanic['survived'])

# %% [markdown]
# ## Select fittest n parents

# %%
# population = parent_pops(titanic,100,'survived')
def fittest_parents(population,lamda):
    parent_scores = parent_score(population)
    fittest_parent = []
    sorted_parents = sorted(parent_scores.items(), key = lambda x:x[1], reverse = True)
    top_lamda_parents_indices = sorted_parents[:lamda]
    top_lamda_parents = [item[0] for item in top_lamda_parents_indices]
    
    for i in top_lamda_parents:
        fittest_parent.append(population[i])
    return fittest_parent

# %%
fittest_parents(parent_pops(titanic,20,'survived'),10)
# Out:
# [       pclass       age     sibsp     parch  adult_male
#  1   -0.372392  0.151664  0.826296 -0.632414       False
#  3   -0.372392 -0.039765  0.826296 -0.632414       False
#  6   -0.372392  1.172618 -0.724074 -0.632414        True
#  10   3.500488 -2.017864  0.826296  0.690567       False
#  11  -0.372392  1.427856 -0.724074 -0.632414       False
#  ..        ...       ...       ...       ...         ...
#  871 -0.372392  0.725950  0.826296  0.690567       False
#  872 -0.372392 -0.167385 -0.724074 -0.632414        True
#  879 -0.372392  1.300237 -0.724074  0.690567       False
#  887 -0.372392 -1.060719 -0.724074 -0.632414       False
#  889 -0.372392 -0.614052 -0.724074 -0.632414        True
#
#  [182 rows x 5 columns],
#         pclass     parch  adult_male  alone
#  1   -0.372392 -0.632414       False  False
#  3   -0.372392 -0.632414       False  False
#  6   -0.372392 -0.632414        True   True
#  10   3.500488  0.690567       False  False
#  11  -0.372392 -0.632414       False   True
#  ..        ...       ...         ...    ...
#  871 -0.372392  0.690567       False  False
#  872 -0.372392 -0.632414        True   True
#  879 -0.372392  0.690567       False  False
#  887 -0.372392 -0.632414       False   True
#  889 -0.372392 -0.632414        True   True
#
#  [182 rows x 4 columns],
#         pclass     parch  adult_male  alone
#  1   -0.372392 -0.632414       False  False
#  3   -0.372392 -0.632414       False  False
#  6   -0.372392 -0.632414        True   True
#  10   3.500488  0.690567       False  False
#  11  -0.372392 -0.632414       False   True
#  ..        ...       ...         ...    ...
#  871 -0.372392  0.690567       False  False
#  872 -0.372392 -0.632414        True   True
#  879 -0.372392  0.690567       False  False
#  887 -0.372392 -0.632414       False   True
#  889 -0.372392 -0.632414        True   True
#
#  [182 rows x 4 columns],
#         pclass     parch      fare  adult_male  alone
#  1   -0.372392 -0.632414 -0.099835       False  False
#  3   -0.372392 -0.632414 -0.337554       False  False
#  6   -0.372392 -0.632414 -0.353732        True   True
#  10   3.500488  0.690567 -0.813428       False  False
#  11  -0.372392 -0.632414 -0.684654       False   True
#  ..        ...       ...       ...         ...    ...
#  871 -0.372392  0.690567 -0.344689       False  False
#  872 -0.372392 -0.632414 -0.966388        True   True
#  879 -0.372392  0.690567  0.055413       False  False
#  887 -0.372392 -0.632414 -0.639551       False   True
#  889 -0.372392 -0.632414 -0.639551        True   True
#
#  [182 rows x 5 columns],
#          parch  adult_male  alone
#  1   -0.632414       False  False
#  3   -0.632414       False  False
#  6   -0.632414        True   True
#  10   0.690567       False  False
#  11  -0.632414       False   True
#  ..        ...         ...    ...
#  871  0.690567       False  False
#  872 -0.632414        True   True
#  879  0.690567       False  False
#  887 -0.632414       False   True
#  889 -0.632414        True   True
#
#  [182 rows x 3 columns],
#            age  adult_male  alone
#  1    0.151664       False  False
#  3   -0.039765       False  False
#  6    1.172618        True   True
#  10  -2.017864       False  False
#  11   1.427856       False   True
#  ..        ...         ...    ...
#  871  0.725950       False  False
#  872 -0.167385        True   True
#  879  1.300237       False  False
#  887 -1.060719       False   True
#  889 -0.614052        True   True
#
#  [182 rows x 3 columns],
#          sibsp      fare  adult_male  alone
#  1    0.826296 -0.099835       False  False
#  3    0.826296 -0.337554       False  False
#  6   -0.724074 -0.353732        True   True
#  10   0.826296 -0.813428       False  False
#  11  -0.724074 -0.684654       False   True
#  ..        ...       ...         ...    ...
#  871  0.826296 -0.344689       False  False
#  872 -0.724074 -0.966388        True   True
#  879 -0.724074  0.055413       False  False
#  887 -0.724074 -0.639551       False   True
#  889 -0.724074 -0.639551        True   True
#
#  [182 rows x 4 columns],
#            age     sibsp     parch      fare  adult_male  alone
#  1    0.151664  0.826296 -0.632414 -0.099835       False  False
#  3   -0.039765  0.826296 -0.632414 -0.337554       False  False
#  6    1.172618 -0.724074 -0.632414 -0.353732        True   True
#  10  -2.017864  0.826296  0.690567 -0.813428       False  False
#  11   1.427856 -0.724074 -0.632414 -0.684654       False   True
#  ..        ...       ...       ...       ...         ...    ...
#  871  0.725950  0.826296  0.690567 -0.344689       False  False
#  872 -0.167385 -0.724074 -0.632414 -0.966388        True   True
#  879  1.300237 -0.724074  0.690567  0.055413       False  False
#  887 -1.060719 -0.724074 -0.632414 -0.639551       False   True
#  889 -0.614052 -0.724074 -0.632414 -0.639551        True   True
#
#  [182 rows x 6 columns],
#         pclass       age
#  1   -0.372392  0.151664
#  3   -0.372392 -0.039765
#  6   -0.372392  1.172618
#  10   3.500488 -2.017864
#  11  -0.372392  1.427856
#  ..        ...       ...
#  871 -0.372392  0.725950
#  872 -0.372392 -0.167385
#  879 -0.372392  1.300237
#  887 -0.372392 -1.060719
#  889 -0.372392 -0.614052
#
#  [182 rows x 2 columns],
#            age     parch      fare  alone
#  1    0.151664 -0.632414 -0.099835  False
#  3   -0.039765 -0.632414 -0.337554  False
#  6    1.172618 -0.632414 -0.353732   True
#  10  -2.017864  0.690567 -0.813428  False
#  11   1.427856 -0.632414 -0.684654   True
#  ..        ...       ...       ...    ...
#  871  0.725950  0.690567 -0.344689  False
#  872 -0.167385 -0.632414 -0.966388   True
#  879  1.300237  0.690567  0.055413  False
#  887 -1.060719 -0.632414 -0.639551   True
#  889 -0.614052 -0.632414 -0.639551   True
#
#  [182 rows x 4 columns]]

# %% [markdown]
# # Define crossover
#     we choose uniform-crossover initially

# %%
def uniform_crossover(data,target_variable,parent1, parent2):
    X = data.drop(target_variable, axis = 1) 
    parent_list1 = parent1.columns.tolist()
    temp = 0
    
    bool_arr1 = np.zeros(X.shape[1])
    for i in parent_list1:
        bool_arr1[X.columns.get_loc(i)] = 1
        
    bool_arr2 = np.zeros(X.shape[1])
    parent_list2 = parent2.columns.tolist()
    for i in parent_list2:
        bool_arr2[X.columns.get_loc(i)] = 1
        
    for i in range(len(bool_arr1)):
        if np.random.uniform() >= 0.5:
            temp = bool_arr1[i]
            bool_arr1[i] = bool_arr2[i]
            bool_arr2[i] = temp
            continue
            
    new_parent1 = X.iloc[:, np.where(bool_arr1)[0]]
    new_parent2 = X.iloc[:, np.where(bool_arr2)[0]]
    return  new_parent1, new_parent2

# %%
population = parent_pops(titanic,2,'survived')
population
# Out:
# [     pclass   age  sibsp
#  1         1  38.0      1
#  3         1  35.0      1
#  6         1  54.0      0
#  10        3   4.0      1
#  11        1  58.0      0
#  ..      ...   ...    ...
#  871       1  47.0      1
#  872       1  33.0      0
#  879       1  56.0      0
#  887       1  19.0      0
#  889       1  26.0      0
#
#  [182 rows x 3 columns],
#       pclass  sibsp  parch     fare  alone
#  1         1      1      0  71.2833  False
#  3         1      1      0  53.1000  False
#  6         1      0      0  51.8625   True
#  10        3      1      1  16.7000  False
#  11        1      0      0  26.5500   True
#  ..      ...    ...    ...      ...    ...
#  871       1      1      1  52.5542  False
#  872       1      0      0   5.0000   True
#  879       1      0      1  83.1583  False
#  887       1      0      0  30.0000   True
#  889       1      0      0  30.0000   True
#
#  [182 rows x 5 columns]]

# %%
#test it 
parent_1 = population[0]
parent_2 = population[1]
uniform_crossover(titanic,'survived',parent_1, parent_2)
# Out:
# (     pclass  sibsp
#  1         1      1
#  3         1      1
#  6         1      0
#  10        3      1
#  11        1      0
#  ..      ...    ...
#  871       1      1
#  872       1      0
#  879       1      0
#  887       1      0
#  889       1      0
#
#  [182 rows x 2 columns],
#       pclass   age  sibsp  parch     fare  alone
#  1         1  38.0      1      0  71.2833  False
#  3         1  35.0      1      0  53.1000  False
#  6         1  54.0      0      0  51.8625   True
#  10        3   4.0      1      1  16.7000  False
#  11        1  58.0      0      0  26.5500   True
#  ..      ...   ...    ...    ...      ...    ...
#  871       1  47.0      1      1  52.5542  False
#  872       1  33.0      0      0   5.0000   True
#  879       1  56.0      0      1  83.1583  False
#  887       1  19.0      0      0  30.0000   True
#  889       1  26.0      0      0  30.0000   True
#
#  [182 rows x 6 columns])

# %% [markdown]
# # Define Mutation
#     we choose random bit-flip mutation initially

# %%
def rbf_mutation(data,target_variable,parent1, parent2,mutation_rate):
    X = data.drop(target_variable, axis = 1)
    
    bool_arr1 = np.zeros(X.shape[1])
    parent_list1 = parent1.columns.tolist()
    for i in parent_list1:
        bool_arr1[X.columns.get_loc(i)] = 1
        
    bool_arr2 = np.zeros(X.shape[1])
    parent_list2 = parent2.columns.tolist()
    for i in parent_list2:
        bool_arr2[X.columns.get_loc(i)] = 1
        
    for i in range(len(bool_arr1)):
        if mutation_rate > np.random.normal(loc = .5, scale = .25, size = 1):
            bool_arr1[i] = 1-bool_arr1[i]
            continue
    for i in range(len(bool_arr2)):
        if mutation_rate > np.random.normal(loc = .5, scale = .25, size = 1):
            bool_arr2[i] = 1-bool_arr2[i]
            continue
            
    new_parent1 = X.iloc[:, np.where(bool_arr1)[0]]
    new_parent2 = X.iloc[:, np.where(bool_arr2)[0]]    
    
    return new_parent1, new_parent2

# %%
rbf_mutation(titanic,'survived',parent_1, parent_2,1)
# Out:
# (     parch     fare  adult_male  alone
#  1        0  71.2833       False  False
#  3        0  53.1000       False  False
#  6        0  51.8625        True   True
#  10       1  16.7000       False  False
#  11       0  26.5500       False   True
#  ..     ...      ...         ...    ...
#  871      1  52.5542       False  False
#  872      0   5.0000        True   True
#  879      1  83.1583       False  False
#  887      0  30.0000       False   True
#  889      0  30.0000        True   True
#
#  [182 rows x 4 columns],
#        age  adult_male
#  1    38.0       False
#  3    35.0       False
#  6    54.0        True
#  10    4.0       False
#  11   58.0       False
#  ..    ...         ...
#  871  47.0       False
#  872  33.0        True
#  879  56.0       False
#  887  19.0       False
#  889  26.0        True
#
#  [182 rows x 2 columns])

# %% [markdown]
# # Define Genetic Algorithm
#     we choose to do it according to the ( µ, λ ) Evolution Strategy

# %%
def gen_alg(data,target_variable,pop_size,no_parents_selected,iterations,mutation_rate): 
    population = parent_pops(data,pop_size,target_variable)
    
    for z in range(iterations):
        parents = fittest_parents(population,no_parents_selected)
        new_gen = []
        for i in range(math.comb(len(parents),2)):
            for j in range(len(parents)):
                parent1 = parents[j]
                for k in range(i+1,len(parents)):            
                    parent2 = parents[k]
                
                    if np.random.normal(loc = .5 , scale = .25 , size = 1) < 0.5:
                        new_gen.append(uniform_crossover(data,target_variable,parent1,parent2))
                    else:
                        new_gen.append(rbf_mutation(data,target_variable,parent1,parent2,mutation_rate))
        population = new_gen

    return fittest_parents(population,1)

# %%
gen_alg(titanic,'survived',100,20,1000,.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 gen_alg(titanic,'survived',100,20,1000,.2)
#
# Cell In[21], line 5, in gen_alg(data, target_variable, pop_size, no_parents_selected, iterations, mutation_rate)
#       2 population = parent_pops(data,pop_size,target_variable)
#       4 for z in range(iterations):
# ----> 5     parents = fittest_parents(population,no_parents_selected)
#       6     new_gen = []
#       7     for i in range(math.comb(len(parents),2)):
#
# Cell In[15], line 3, in fittest_parents(population, lamda)
#       2 def fittest_parents(population,lamda):
# ----> 3     parent_scores = parent_score(population)
#       4     fittest_parent = []
#       5     sorted_parents = sorted(parent_scores.items(), key = lambda x:x[1], reverse = True)
#
# Cell In[13], line 5, in parent_score(keys)
#       3 temp_var = 0
#       4 for key in keys:
# ----> 5     theta1 = gradient_descend(key, y, learning_rate = 0.01, n_iter = 1000)
#       6     aic = -1*calculate_aic(key,y,theta1)
#       7     pop_score[temp_var] = aic
#
# Cell In[8], line 2, in gradient_descend(X, y, learning_rate, n_iter)
#       1 def gradient_descend(X, y, learning_rate = 0.01, n_iter = 1000):
# ----> 2     X = normalize(X)
#       3     X = np.c_[np.ones(X.shape[0]), X]
#       4     theta = np.zeros(X.shape[1])
#
# Cell In[7], line 2, in normalize(X)
#       1 def normalize(X):
# ----> 2     for i in pd.DataFrame(X).columns:
#       3         if X[i].dtype == 'bool':
#       4             X[i] = X[i]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:822, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     814         mgr = arrays_to_mgr(
#     815             arrays,
#     816             columns,
#    (...)
#     819             typ=manager,
#     820         )
#     821     else:
# --> 822         mgr = ndarray_to_mgr(
#     823             data,
#     824             index,
#     825             columns,
#     826             dtype=dtype,
#     827             copy=copy,
#     828             typ=manager,
#     829         )
#     830 else:
#     831     mgr = dict_to_mgr(
#     832         {},
#     833         index,
#    (...)
#     836         typ=manager,
#     837     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:319, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
# --> 319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#     321 if dtype is not None and values.dtype != dtype:
#     322     # GH#40110 see similar check inside sanitize_array
#     323     values = sanitize_array(
#     324         values,
#     325         None,
#    (...)
#     328         allow_2d=True,
#     329     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:575, in _prep_ndarraylike(values, copy)
#     569 # we could have a 1-dim or 2-dim list here
#     570 # this is equiv of np.asarray, but does object conversion
#     571 # and platform dtype preservation
#     572 # does not convert e.g. [1, "a", True] to ["1", "a", "True"] like
#     573 #  np.asarray would
#     574 if is_list_like(values[0]):
# --> 575     values = np.array([convert(v) for v in values])
#     576 elif isinstance(values[0], np.ndarray) and values[0].ndim == 0:
#     577     # GH#21861 see test_constructor_list_of_lists
#     578     values = np.array([convert(v) for v in values])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 182) + inhomogeneous part.
